# %%
import numpy as np
import pandas as pd

# %%
array = np.array([3,4,5])
series = pd.Series(array)
series = pd.Series(array, index=[2024,2025,2026])
series
# Out:
# 2024    3
# 2025    4
# 2026    5
# dtype: int64

# %%
lists = [[3,6], [4,8], [5,10]]
data_frame = pd.DataFrame(lists, columns=\
['original', '2x'], index = [2024,2025,2026])
data_frame
# Out:
#       original  2x
# 2024         3   6
# 2025         4   8
# 2026         5  10

# %%
l = np.array([1, 3, 4, 2])
l > 3
# Out:
# array([False, False,  True, False])
