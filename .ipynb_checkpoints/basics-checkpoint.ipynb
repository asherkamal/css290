# %%
height = 3.2

# %%
height
# Out:
# 3.2

# %%
#double the height
height*2 #multiply by two
# Out:
# 6.4

# %%
grades = [3.5, 2.9, 3.8, 3.1]

# %%
grades[2]
# Out:
# 3.8

# %%
grades[1:3]
# Out:
# [2.9, 3.8]

# %%
grades * 2
# Out:
# [3.5, 2.9, 3.8, 3.1, 3.5, 2.9, 3.8, 3.1]

# %%
print("hello")
# Out:
# hello

# %%
print('hello')
# Out:
# hello

# %%
print('cheese' + 'burger')
# Out:
# cheeseburger

# %%
print('Cost = $' + str(32.46))
# Out:
# Cost = $32.46

# %%
x = -1
if x > 0:
    print("positive")

# %%
x = 4
if x > 0:
    print("positive")
else:
    print("not positive")
# Out:
# positive

# %%
x = 0
if x > 0:
    print("positive")
elif x == 0:
    print("zero")
else:
    print("negative")
# Out:
# zero

# %%
for grade in grades:
    print(grade)
print("That's all")
# Out:
# 3.5
# 2.9
# 3.8
# 3.1
# That's all

# %%
import math
def init_list(init_value=0, size=10):
    return [init_value] * size

# %%
init_list (init_value = "*", size = 6)
# Out:
# ['*', '*', '*', '*', '*', '*']
